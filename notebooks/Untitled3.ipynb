# %%
import numpy as np
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd
from env.util import *
from env.constants import *

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
data_file = './data/NODIFF_TEST.parquet'

# %%
df = pq.read_table(data_file).to_pandas()
ind = df[STATE_FIELDS.keys()]
ind.rename(columns=STATE_FIELDS, inplace=True)

# %%
ind[['bid_price']].plot(figsize=(30,30), )

# %%
ind[['bid_qty']].plot(figsize=(40,40), )

# %%
h = ind.head(n=100)

# %%
np.std(h['bid_qty'])
# Out:
# 2691.0856336244674

# %%
h.iloc[0]['bid_price']
# Out:
# 11750.6

# %%
h[['bid_qty']].plot()

# %%
h[['bid_price']].plot()
