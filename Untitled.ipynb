# %%
import pyarrow as pa 
import pyarrow.parquet as pq 
import numpy as np 
import pandas as pd

# %%
df = pq.read_table('./data/DATA.parquet').to_pandas()

# %%
df[[c for c in df.columns if 'price' in c]].plot(figsize=(40,40))
